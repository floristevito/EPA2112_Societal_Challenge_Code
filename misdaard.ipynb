# %%
import pandas as pd

# %%
df = pd.read_csv('data/Misdrijven_per_wijk_en_buurt_per_maand_20102021_110817.csv', sep= ';')
df
# Out:
#             Soort misdrijf        Perioden Wijken en buurten  \
# 0        Totaal misdrijven    2020 oktober          Houtwijk
# 1        Totaal misdrijven   2020 november          Houtwijk
# 2        Totaal misdrijven   2020 december          Houtwijk
# 3        Totaal misdrijven    2021 januari          Houtwijk
# 4        Totaal misdrijven   2021 februari          Houtwijk
# ..                     ...             ...               ...
# 703  3.9.3 Fraude (overig)        2021 mei          Houtwijk
# 704  3.9.3 Fraude (overig)       2021 juni          Houtwijk
# 705  3.9.3 Fraude (overig)       2021 juli          Houtwijk
# 706  3.9.3 Fraude (overig)   2021 augustus          Houtwijk
# 707  3.9.3 Fraude (overig)  2021 september          Houtwijk
#
#      Geregistreerde misdrijven (aantal)
# 0                                  49.0
# 1                                  46.0
# 2                                  58.0
# 3                                  45.0
# ...

# %%
df.groupby(['Soort misdrijf', 'Wijken en buurten']
).sum().sort_values('Geregistreerde misdrijven (aantal)', ascending=False)
# Out:
#                                                             Geregistreerde misdrijven (aantal)
# Soort misdrijf                           Wijken en buurten
# Totaal misdrijven                        Houtwijk                                        596.0
# 3.9.1 Horizontale fraude                 Houtwijk                                        102.0
# 1.6.2 Overige vermogensdelicten          Houtwijk                                         69.0
# 1.3.1 Ongevallen (weg)                   Houtwijk                                         56.0
# 2.2.1 Vernieling cq. zaakbeschadiging    Houtwijk                                         47.0
# 1.2.3 Diefstal van brom-, snor-, fietsen Houtwijk                                         46.0
# 1.1.1 Diefstal/inbraak woning            Houtwijk                                         44.0
# 1.2.5 Diefstal af/uit/van ov. voertuigen Houtwijk                                         39.0
# ...
